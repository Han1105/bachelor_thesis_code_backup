# %%
from qiskit.quantum_info import SparsePauliOp, Statevector
from qiskit.quantum_info import SparsePauliOp, Pauli
from qiskit_nature.second_q.drivers import PySCFDriver
from qiskit_nature.second_q.mappers import ParityMapper
from qiskit_nature.units import DistanceUnit
import numpy as np
from qiskit_nature.second_q.mappers import JordanWignerMapper
from qiskit.circuit import QuantumCircuit
from qiskit.circuit.library import PauliEvolutionGate
from qiskit.quantum_info import SparsePauliOp
from qiskit.synthesis.evolution import SuzukiTrotter
from qiskit import transpile
from qiskit.transpiler import CouplingMap
from qiskit.transpiler import CouplingMap
import matplotlib.pyplot as plt
import numpy as np

# %%
from qiskit import QuantumCircuit

# 创建一个含 4 个量子比特的电路（你图中从 q0 到 q3）
qc = QuantumCircuit(4)

# 在 q[0] 和 q[1] 之间添加一个 CNOT 门
qc.cx(0, 1)

qc.draw('mpl')  # 可视化电路（Jupyter Notebook 中）

# %%
from qiskit import transpile
from qiskit.transpiler import CouplingMap
from qiskit.visualization import plot_coupling_map
import matplotlib.pyplot as plt
total_count_list = []
basis_gates = ['cz', 'id', 'rx', 'rz', 'rzz', 'sx', 'x']
linear_coupling1= CouplingMap(couplinglist=[(0, 1), (1, 0), (1, 2), (2, 1), (2, 3), (3, 2)])
t1 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling,
        optimization_level=1
    )
print("1:", t1.count_ops())

linear_coupling2 = CouplingMap(couplinglist=[(0, 1), (1, 0), (1, 3), (3, 1), (2, 3), (3, 2)])
t2 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling2,
        optimization_level=1
    )
print("2:", t2.count_ops())

linear_coupling3 = CouplingMap(couplinglist=[(0, 2), (2, 0), (1, 2), (2, 1), (1, 3), (3, 1)])
t3 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling3,
        optimization_level=1
    )
print("3:", t3.count_ops())

linear_coupling4 = CouplingMap(couplinglist=[(0, 2), (2, 0), (2, 3), (3, 2), (1, 3), (3, 1)])
t4 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling4,
        optimization_level=1
    )
print("4:", t4.count_ops())
linear_coupling5 = CouplingMap(couplinglist=[(0, 3), (3, 0), (1, 3), (3, 1), (1, 2), (2, 1)])
t5 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling5,
        optimization_level=1
    )
print("5:", t5.count_ops())

linear_coupling6 = CouplingMap(couplinglist=[(0, 3), (3, 0), (2, 3), (3, 2), (1, 2), (2, 1)])
t6 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling6,
        optimization_level=1
    )
print("6:", t6.count_ops())

linear_coupling7 = CouplingMap(couplinglist=[(1, 0), (0, 1), (0, 2), (2, 0), (2, 3), (3, 2)])
t7 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling7,
        optimization_level=1
    )
print("7:", t7.count_ops())
linear_coupling8 = CouplingMap(couplinglist=[(1, 0), (0, 1), (0, 3), (3, 0), (2, 3), (3, 2)])
t8 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling8,
        optimization_level=1
    )
print("8:", t8.count_ops())

linear_coupling9 = CouplingMap(couplinglist=[(1, 2), (2, 1), (2, 3), (3, 2), (0, 3), (3, 0)])
t9 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling9,
        optimization_level=1
    )
print("9:", t9.count_ops())

linear_coupling10 = CouplingMap(couplinglist=[(1, 2), (2, 1), (2, 0), (0, 2), (0, 3), (3, 0)])
t10 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling10,
        optimization_level=1
    )
print("10:", t10.count_ops())

linear_coupling11 = CouplingMap(couplinglist=[(1, 3), (3, 1), (0, 2), (2, 0), (0, 3), (3, 0)])
t11 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling11,
        optimization_level=1
    )
print("11:", t11.count_ops())
linear_coupling12 = CouplingMap(couplinglist=[(1, 3), (3, 1), (0, 2), (2, 0), (2, 3), (3, 2)])
t12 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling12,
        optimization_level=1
    )
print("12:", t12.count_ops())

linear_coupling13 = CouplingMap(couplinglist=[(2, 0), (0, 2), (1, 0), (0, 1), (1, 3), (3, 1)])
t13 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling13,
        optimization_level=1
    )
print("13:", t13.count_ops())
linear_coupling14 = CouplingMap(couplinglist=[(2, 0), (0, 2), (3, 0), (0, 3), (1, 3), (3, 1)])
t14 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling14,
        optimization_level=1
    )
print("14:", t14.count_ops())

linear_coupling15 = CouplingMap(couplinglist=[(2, 1), (1, 2), (0, 1), (1, 0), (0, 3), (3, 0)])
t15 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling15,
        optimization_level=1
    )
print("15:", t15.count_ops())
linear_coupling16 = CouplingMap(couplinglist=[(2, 1), (1, 2), (0, 3), (3, 0), (3, 1), (1, 3)])
t16 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling16,
        optimization_level=1
    )
print("16:", t16.count_ops())

linear_coupling17 = CouplingMap(couplinglist=[(2, 3), (3, 2), (0, 1), (1, 0), (1, 3), (3, 1)])
t17 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling17,
        optimization_level=1
    )
print("17:", t17.count_ops())

linear_coupling18 = CouplingMap(couplinglist=[(2, 3), (3, 2), (0, 1), (1, 0), (0, 3), (3, 0)])
t18 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling18,
        optimization_level=1
    )
print("18:", t18.count_ops())

linear_coupling19 = CouplingMap(couplinglist=[(3, 0), (0, 3), (1, 0), (0, 1), (1, 2), (2, 1)])
t19 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling19,
        optimization_level=1
    )
print("19:", t19.count_ops())
linear_coupling20 = CouplingMap(couplinglist=[(3, 0), (0, 3), (2, 0), (0, 2), (1, 2), (2, 1)])
t20 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling20,
        optimization_level=1
    )
print("20:", t20.count_ops())

linear_coupling21 = CouplingMap(couplinglist=[(3, 1), (1, 3), (0, 1), (1, 0), (0, 2), (2, 0)])
t21 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling21,
        optimization_level=1
    )
print("21:", t21.count_ops())
linear_coupling22 = CouplingMap(couplinglist=[(3, 1), (1, 3), (0, 2), (2, 0), (2, 1), (1, 2)])
t22 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling22,
        optimization_level=1
    )
print("22:", t22.count_ops())

linear_coupling23 = CouplingMap(couplinglist=[(3, 2), (2, 3), (0, 1), (1, 0), (0, 2), (2, 0)])
t23 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling23,
        optimization_level=1
    )
print("23:", t23.count_ops())
linear_coupling24 = CouplingMap(couplinglist=[(3, 2), (2, 3), (0, 1), (1, 0), (1, 2), (2, 1)])
t24 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling24,
        optimization_level=1
    )
print("24:", t24.count_ops())
# Out:
# 1: OrderedDict([('rz', 4), ('sx', 2), ('cz', 1)])
# 2: OrderedDict([('rz', 4), ('sx', 2), ('cz', 1)])
# 3: OrderedDict([('rz', 4), ('sx', 2), ('cz', 1)])
# 4: OrderedDict([('rz', 4), ('sx', 2), ('cz', 1)])
# 5: OrderedDict([('rz', 4), ('sx', 2), ('cz', 1)])
# 6: OrderedDict([('rz', 4), ('sx', 2), ('cz', 1)])
# 7: OrderedDict([('rz', 4), ('sx', 2), ('cz', 1)])
# 8: OrderedDict([('rz', 4), ('sx', 2), ('cz', 1)])
# 9: OrderedDict([('rz', 4), ('sx', 2), ('cz', 1)])
# 10: OrderedDict([('rz', 4), ('sx', 2), ('cz', 1)])
# 11: OrderedDict([('rz', 4), ('sx', 2), ('cz', 1)])
# 12: OrderedDict([('rz', 4), ('sx', 2), ('cz', 1)])
# 13: OrderedDict([('rz', 4), ('sx', 2), ('cz', 1)])
# 14: OrderedDict([('rz', 4), ('sx', 2), ('cz', 1)])
# 15: OrderedDict([('rz', 4), ('sx', 2), ('cz', 1)])
# 16: OrderedDict([('rz', 4), ('sx', 2), ('cz', 1)])
# 17: OrderedDict([('rz', 4), ('sx', 2), ('cz', 1)])
# 18: OrderedDict([('rz', 4), ('sx', 2), ('cz', 1)])
# 19: OrderedDict([('rz', 4), ('sx', 2), ('cz', 1)])
# ...

# %%
total_count_list = []
basis_gates = ['cx', 'rz', 'sx']
linear_coupling1= CouplingMap(couplinglist=[(0, 1), (1, 0), (1, 2), (2, 1), (2, 3), (3, 2)])
t1 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling,
        optimization_level=1
    )
print("1:", t1.count_ops())

linear_coupling2 = CouplingMap(couplinglist=[(0, 1), (1, 0), (1, 3), (3, 1), (2, 3), (3, 2)])
t2 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling2,
        optimization_level=1
    )
print("2:", t2.count_ops())

linear_coupling3 = CouplingMap(couplinglist=[(0, 2), (2, 0), (1, 2), (2, 1), (1, 3), (3, 1)])
t3 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling3,
        optimization_level=1
    )
print("3:", t3.count_ops())

linear_coupling4 = CouplingMap(couplinglist=[(0, 2), (2, 0), (2, 3), (3, 2), (1, 3), (3, 1)])
t4 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling4,
        optimization_level=1
    )
print("4:", t4.count_ops())
linear_coupling5 = CouplingMap(couplinglist=[(0, 3), (3, 0), (1, 3), (3, 1), (1, 2), (2, 1)])
t5 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling5,
        optimization_level=1
    )
print("5:", t5.count_ops())

linear_coupling6 = CouplingMap(couplinglist=[(0, 3), (3, 0), (2, 3), (3, 2), (1, 2), (2, 1)])
t6 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling6,
        optimization_level=1
    )
print("6:", t6.count_ops())

linear_coupling7 = CouplingMap(couplinglist=[(1, 0), (0, 1), (0, 2), (2, 0), (2, 3), (3, 2)])
t7 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling7,
        optimization_level=1
    )
print("7:", t7.count_ops())
linear_coupling8 = CouplingMap(couplinglist=[(1, 0), (0, 1), (0, 3), (3, 0), (2, 3), (3, 2)])
t8 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling8,
        optimization_level=1
    )
print("8:", t8.count_ops())

linear_coupling9 = CouplingMap(couplinglist=[(1, 2), (2, 1), (2, 3), (3, 2), (0, 3), (3, 0)])
t9 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling9,
        optimization_level=1
    )
print("9:", t9.count_ops())

linear_coupling10 = CouplingMap(couplinglist=[(1, 2), (2, 1), (2, 0), (0, 2), (0, 3), (3, 0)])
t10 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling10,
        optimization_level=1
    )
print("10:", t10.count_ops())

linear_coupling11 = CouplingMap(couplinglist=[(1, 3), (3, 1), (0, 2), (2, 0), (0, 3), (3, 0)])
t11 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling11,
        optimization_level=1
    )
print("11:", t11.count_ops())
linear_coupling12 = CouplingMap(couplinglist=[(1, 3), (3, 1), (0, 2), (2, 0), (2, 3), (3, 2)])
t12 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling12,
        optimization_level=1
    )
print("12:", t12.count_ops())

linear_coupling13 = CouplingMap(couplinglist=[(2, 0), (0, 2), (1, 0), (0, 1), (1, 3), (3, 1)])
t13 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling13,
        optimization_level=1
    )
print("13:", t13.count_ops())
linear_coupling14 = CouplingMap(couplinglist=[(2, 0), (0, 2), (3, 0), (0, 3), (1, 3), (3, 1)])
t14 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling14,
        optimization_level=1
    )
print("14:", t14.count_ops())

linear_coupling15 = CouplingMap(couplinglist=[(2, 1), (1, 2), (0, 1), (1, 0), (0, 3), (3, 0)])
t15 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling15,
        optimization_level=1
    )
print("15:", t15.count_ops())
linear_coupling16 = CouplingMap(couplinglist=[(2, 1), (1, 2), (0, 3), (3, 0), (3, 1), (1, 3)])
t16 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling16,
        optimization_level=1
    )
print("16:", t16.count_ops())

linear_coupling17 = CouplingMap(couplinglist=[(2, 3), (3, 2), (0, 1), (1, 0), (1, 3), (3, 1)])
t17 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling17,
        optimization_level=1
    )
print("17:", t17.count_ops())

linear_coupling18 = CouplingMap(couplinglist=[(2, 3), (3, 2), (0, 1), (1, 0), (0, 3), (3, 0)])
t18 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling18,
        optimization_level=1
    )
print("18:", t18.count_ops())

linear_coupling19 = CouplingMap(couplinglist=[(3, 0), (0, 3), (1, 0), (0, 1), (1, 2), (2, 1)])
t19 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling19,
        optimization_level=1
    )
print("19:", t19.count_ops())
linear_coupling20 = CouplingMap(couplinglist=[(3, 0), (0, 3), (2, 0), (0, 2), (1, 2), (2, 1)])
t20 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling20,
        optimization_level=1
    )
print("20:", t20.count_ops())

linear_coupling21 = CouplingMap(couplinglist=[(3, 1), (1, 3), (0, 1), (1, 0), (0, 2), (2, 0)])
t21 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling21,
        optimization_level=1
    )
print("21:", t21.count_ops())
linear_coupling22 = CouplingMap(couplinglist=[(3, 1), (1, 3), (0, 2), (2, 0), (2, 1), (1, 2)])
t22 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling22,
        optimization_level=1
    )
print("22:", t22.count_ops())

linear_coupling23 = CouplingMap(couplinglist=[(3, 2), (2, 3), (0, 1), (1, 0), (0, 2), (2, 0)])
t23 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling23,
        optimization_level=1
    )
print("23:", t23.count_ops())
linear_coupling24 = CouplingMap(couplinglist=[(3, 2), (2, 3), (0, 1), (1, 0), (1, 2), (2, 1)])
t24 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling24,
        optimization_level=1
    )
print("24:", t24.count_ops())
# Out:
# 1: OrderedDict([('cx', 1)])
# 2: OrderedDict([('cx', 1)])
# 3: OrderedDict([('cx', 1)])
# 4: OrderedDict([('cx', 1)])
# 5: OrderedDict([('cx', 1)])
# 6: OrderedDict([('cx', 1)])
# 7: OrderedDict([('cx', 1)])
# 8: OrderedDict([('cx', 1)])
# 9: OrderedDict([('cx', 1)])
# 10: OrderedDict([('cx', 1)])
# 11: OrderedDict([('cx', 1)])
# 12: OrderedDict([('cx', 1)])
# 13: OrderedDict([('cx', 1)])
# 14: OrderedDict([('cx', 1)])
# 15: OrderedDict([('cx', 1)])
# 16: OrderedDict([('cx', 1)])
# 17: OrderedDict([('cx', 1)])
# 18: OrderedDict([('cx', 1)])
# 19: OrderedDict([('cx', 1)])
# 20: OrderedDict([('cx', 1)])
# 21: OrderedDict([('cx', 1)])
# 22: OrderedDict([('cx', 1)])
# 23: OrderedDict([('cx', 1)])
# 24: OrderedDict([('cx', 1)])

# %%
total_count_list = []
basis_gates = ['cx', 'rz', 'sx']
linear_coupling1= CouplingMap(couplinglist=[(0, 1), (1, 0), (1, 2), (2, 1), (2, 3), (3, 2)])
t1 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling,
        optimization_level=0
    )
print("1:", t1.count_ops())

linear_coupling2 = CouplingMap(couplinglist=[(0, 1), (1, 0), (1, 3), (3, 1), (2, 3), (3, 2)])
t2 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling2,
        optimization_level=0
    )
print("2:", t2.count_ops())

linear_coupling3 = CouplingMap(couplinglist=[(0, 2), (2, 0), (1, 2), (2, 1), (1, 3), (3, 1)])
t3 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling3,
        optimization_level=0
    )
print("3:", t3.count_ops())

linear_coupling4 = CouplingMap(couplinglist=[(0, 2), (2, 0), (2, 3), (3, 2), (1, 3), (3, 1)])
t4 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling4,
        optimization_level=0
    )
print("4:", t4.count_ops())
linear_coupling5 = CouplingMap(couplinglist=[(0, 3), (3, 0), (1, 3), (3, 1), (1, 2), (2, 1)])
t5 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling5,
        optimization_level=0
    )
print("5:", t5.count_ops())

linear_coupling6 = CouplingMap(couplinglist=[(0, 3), (3, 0), (2, 3), (3, 2), (1, 2), (2, 1)])
t6 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling6,
        optimization_level=0
    )
print("6:", t6.count_ops())

linear_coupling7 = CouplingMap(couplinglist=[(1, 0), (0, 1), (0, 2), (2, 0), (2, 3), (3, 2)])
t7 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling7,
        optimization_level=0
    )
print("7:", t7.count_ops())
linear_coupling8 = CouplingMap(couplinglist=[(1, 0), (0, 1), (0, 3), (3, 0), (2, 3), (3, 2)])
t8 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling8,
        optimization_level=0
    )
print("8:", t8.count_ops())

linear_coupling9 = CouplingMap(couplinglist=[(1, 2), (2, 1), (2, 3), (3, 2), (0, 3), (3, 0)])
t9 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling9,
        optimization_level=0
    )
print("9:", t9.count_ops())

linear_coupling10 = CouplingMap(couplinglist=[(1, 2), (2, 1), (2, 0), (0, 2), (0, 3), (3, 0)])
t10 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling10,
        optimization_level=0
    )
print("10:", t10.count_ops())

linear_coupling11 = CouplingMap(couplinglist=[(1, 3), (3, 1), (0, 2), (2, 0), (0, 3), (3, 0)])
t11 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling11,
        optimization_level=0
    )
print("11:", t11.count_ops())
linear_coupling12 = CouplingMap(couplinglist=[(1, 3), (3, 1), (0, 2), (2, 0), (2, 3), (3, 2)])
t12 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling12,
        optimization_level=0
    )
print("12:", t12.count_ops())

linear_coupling13 = CouplingMap(couplinglist=[(2, 0), (0, 2), (1, 0), (0, 1), (1, 3), (3, 1)])
t13 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling13,
        optimization_level=0
    )
print("13:", t13.count_ops())
linear_coupling14 = CouplingMap(couplinglist=[(2, 0), (0, 2), (3, 0), (0, 3), (1, 3), (3, 1)])
t14 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling14,
        optimization_level=0
    )
print("14:", t14.count_ops())

linear_coupling15 = CouplingMap(couplinglist=[(2, 1), (1, 2), (0, 1), (1, 0), (0, 3), (3, 0)])
t15 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling15,
        optimization_level=0
    )
print("15:", t15.count_ops())
linear_coupling16 = CouplingMap(couplinglist=[(2, 1), (1, 2), (0, 3), (3, 0), (3, 1), (1, 3)])
t16 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling16,
        optimization_level=0
    )
print("16:", t16.count_ops())

linear_coupling17 = CouplingMap(couplinglist=[(2, 3), (3, 2), (0, 1), (1, 0), (1, 3), (3, 1)])
t17 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling17,
        optimization_level=0
    )
print("17:", t17.count_ops())

linear_coupling18 = CouplingMap(couplinglist=[(2, 3), (3, 2), (0, 1), (1, 0), (0, 3), (3, 0)])
t18 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling18,
        optimization_level=0
    )
print("18:", t18.count_ops())

linear_coupling19 = CouplingMap(couplinglist=[(3, 0), (0, 3), (1, 0), (0, 1), (1, 2), (2, 1)])
t19 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling19,
        optimization_level=0
    )
print("19:", t19.count_ops())
linear_coupling20 = CouplingMap(couplinglist=[(3, 0), (0, 3), (2, 0), (0, 2), (1, 2), (2, 1)])
t20 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling20,
        optimization_level=0
    )
print("20:", t20.count_ops())

linear_coupling21 = CouplingMap(couplinglist=[(3, 1), (1, 3), (0, 1), (1, 0), (0, 2), (2, 0)])
t21 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling21,
        optimization_level=0
    )
print("21:", t21.count_ops())
linear_coupling22 = CouplingMap(couplinglist=[(3, 1), (1, 3), (0, 2), (2, 0), (2, 1), (1, 2)])
t22 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling22,
        optimization_level=0
    )
print("22:", t22.count_ops())

linear_coupling23 = CouplingMap(couplinglist=[(3, 2), (2, 3), (0, 1), (1, 0), (0, 2), (2, 0)])
t23 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling23,
        optimization_level=0
    )
print("23:", t23.count_ops())
linear_coupling24 = CouplingMap(couplinglist=[(3, 2), (2, 3), (0, 1), (1, 0), (1, 2), (2, 1)])
t24 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling24,
        optimization_level=0
    )
print("24:", t24.count_ops())
# Out:
# 1: OrderedDict([('cx', 1)])
# 2: OrderedDict([('cx', 1)])
# 3: OrderedDict([('cx', 4)])
# 4: OrderedDict([('cx', 7)])
# 5: OrderedDict([('cx', 4)])
# 6: OrderedDict([('cx', 7)])
# 7: OrderedDict([('cx', 1)])
# 8: OrderedDict([('cx', 1)])
# 9: OrderedDict([('cx', 7)])
# 10: OrderedDict([('cx', 4)])
# 11: OrderedDict([('cx', 4)])
# 12: OrderedDict([('cx', 7)])
# 13: OrderedDict([('cx', 1)])
# 14: OrderedDict([('cx', 4)])
# 15: OrderedDict([('cx', 1)])
# 16: OrderedDict([('cx', 4)])
# 17: OrderedDict([('cx', 1)])
# 18: OrderedDict([('cx', 1)])
# 19: OrderedDict([('cx', 1)])
# 20: OrderedDict([('cx', 4)])
# 21: OrderedDict([('cx', 1)])
# 22: OrderedDict([('cx', 4)])
# 23: OrderedDict([('cx', 1)])
# 24: OrderedDict([('cx', 1)])

# %%
total_count_list = []
basis_gates = ['cz', 'id', 'rx', 'rz', 'rzz', 'sx', 'x']
linear_coupling1= CouplingMap(couplinglist=[(0, 1), (1, 0), (1, 2), (2, 1), (2, 3), (3, 2)])
t1 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling,
        optimization_level=0
    )
print("1:", t1.count_ops())

linear_coupling2 = CouplingMap(couplinglist=[(0, 1), (1, 0), (1, 3), (3, 1), (2, 3), (3, 2)])
t2 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling2,
        optimization_level=0
    )
print("2:", t2.count_ops())

linear_coupling3 = CouplingMap(couplinglist=[(0, 2), (2, 0), (1, 2), (2, 1), (1, 3), (3, 1)])
t3 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling3,
        optimization_level=0
    )
print("3:", t3.count_ops())

linear_coupling4 = CouplingMap(couplinglist=[(0, 2), (2, 0), (2, 3), (3, 2), (1, 3), (3, 1)])
t4 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling4,
        optimization_level=0
    )
print("4:", t4.count_ops())
linear_coupling5 = CouplingMap(couplinglist=[(0, 3), (3, 0), (1, 3), (3, 1), (1, 2), (2, 1)])
t5 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling5,
        optimization_level=0
    )
print("5:", t5.count_ops())

linear_coupling6 = CouplingMap(couplinglist=[(0, 3), (3, 0), (2, 3), (3, 2), (1, 2), (2, 1)])
t6 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling6,
        optimization_level=0
    )
print("6:", t6.count_ops())

linear_coupling7 = CouplingMap(couplinglist=[(1, 0), (0, 1), (0, 2), (2, 0), (2, 3), (3, 2)])
t7 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling7,
        optimization_level=0
    )
print("7:", t7.count_ops())
linear_coupling8 = CouplingMap(couplinglist=[(1, 0), (0, 1), (0, 3), (3, 0), (2, 3), (3, 2)])
t8 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling8,
        optimization_level=0
    )
print("8:", t8.count_ops())

linear_coupling9 = CouplingMap(couplinglist=[(1, 2), (2, 1), (2, 3), (3, 2), (0, 3), (3, 0)])
t9 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling9,
        optimization_level=0
    )
print("9:", t9.count_ops())

linear_coupling10 = CouplingMap(couplinglist=[(1, 2), (2, 1), (2, 0), (0, 2), (0, 3), (3, 0)])
t10 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling10,
        optimization_level=0
    )
print("10:", t10.count_ops())

linear_coupling11 = CouplingMap(couplinglist=[(1, 3), (3, 1), (0, 2), (2, 0), (0, 3), (3, 0)])
t11 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling11,
        optimization_level=0
    )
print("11:", t11.count_ops())
linear_coupling12 = CouplingMap(couplinglist=[(1, 3), (3, 1), (0, 2), (2, 0), (2, 3), (3, 2)])
t12 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling12,
        optimization_level=0
    )
print("12:", t12.count_ops())

linear_coupling13 = CouplingMap(couplinglist=[(2, 0), (0, 2), (1, 0), (0, 1), (1, 3), (3, 1)])
t13 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling13,
        optimization_level=0
    )
print("13:", t13.count_ops())
linear_coupling14 = CouplingMap(couplinglist=[(2, 0), (0, 2), (3, 0), (0, 3), (1, 3), (3, 1)])
t14 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling14,
        optimization_level=0
    )
print("14:", t14.count_ops())

linear_coupling15 = CouplingMap(couplinglist=[(2, 1), (1, 2), (0, 1), (1, 0), (0, 3), (3, 0)])
t15 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling15,
        optimization_level=0
    )
print("15:", t15.count_ops())
linear_coupling16 = CouplingMap(couplinglist=[(2, 1), (1, 2), (0, 3), (3, 0), (3, 1), (1, 3)])
t16 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling16,
        optimization_level=0
    )
print("16:", t16.count_ops())

linear_coupling17 = CouplingMap(couplinglist=[(2, 3), (3, 2), (0, 1), (1, 0), (1, 3), (3, 1)])
t17 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling17,
        optimization_level=0
    )
print("17:", t17.count_ops())

linear_coupling18 = CouplingMap(couplinglist=[(2, 3), (3, 2), (0, 1), (1, 0), (0, 3), (3, 0)])
t18 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling18,
        optimization_level=0
    )
print("18:", t18.count_ops())

linear_coupling19 = CouplingMap(couplinglist=[(3, 0), (0, 3), (1, 0), (0, 1), (1, 2), (2, 1)])
t19 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling19,
        optimization_level=0
    )
print("19:", t19.count_ops())
linear_coupling20 = CouplingMap(couplinglist=[(3, 0), (0, 3), (2, 0), (0, 2), (1, 2), (2, 1)])
t20 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling20,
        optimization_level=0
    )
print("20:", t20.count_ops())

linear_coupling21 = CouplingMap(couplinglist=[(3, 1), (1, 3), (0, 1), (1, 0), (0, 2), (2, 0)])
t21 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling21,
        optimization_level=0
    )
print("21:", t21.count_ops())
linear_coupling22 = CouplingMap(couplinglist=[(3, 1), (1, 3), (0, 2), (2, 0), (2, 1), (1, 2)])
t22 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling22,
        optimization_level=0
    )
print("22:", t22.count_ops())

linear_coupling23 = CouplingMap(couplinglist=[(3, 2), (2, 3), (0, 1), (1, 0), (0, 2), (2, 0)])
t23 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling23,
        optimization_level=0
    )
print("23:", t23.count_ops())
linear_coupling24 = CouplingMap(couplinglist=[(3, 2), (2, 3), (0, 1), (1, 0), (1, 2), (2, 1)])
t24 = transpile(
        qc,
        basis_gates=basis_gates,
        coupling_map=linear_coupling24,
        optimization_level=0
    )
print("24:", t24.count_ops())
# Out:
# 1: OrderedDict([('rz', 4), ('sx', 2), ('cz', 1)])
# 2: OrderedDict([('rz', 4), ('sx', 2), ('cz', 1)])
# 3: OrderedDict([('sx', 8), ('cz', 4), ('rz', 4)])
# 4: OrderedDict([('sx', 14), ('cz', 7), ('rz', 4)])
# 5: OrderedDict([('sx', 8), ('cz', 4), ('rz', 4)])
# 6: OrderedDict([('sx', 14), ('cz', 7), ('rz', 4)])
# 7: OrderedDict([('rz', 4), ('sx', 2), ('cz', 1)])
# 8: OrderedDict([('rz', 4), ('sx', 2), ('cz', 1)])
# 9: OrderedDict([('sx', 14), ('cz', 7), ('rz', 4)])
# 10: OrderedDict([('sx', 8), ('cz', 4), ('rz', 4)])
# 11: OrderedDict([('sx', 8), ('rz', 4), ('cz', 4)])
# 12: OrderedDict([('sx', 14), ('cz', 7), ('rz', 4)])
# 13: OrderedDict([('rz', 4), ('sx', 2), ('cz', 1)])
# 14: OrderedDict([('sx', 8), ('cz', 4), ('rz', 4)])
# 15: OrderedDict([('rz', 4), ('sx', 2), ('cz', 1)])
# 16: OrderedDict([('sx', 8), ('cz', 4), ('rz', 4)])
# 17: OrderedDict([('rz', 4), ('sx', 2), ('cz', 1)])
# 18: OrderedDict([('rz', 4), ('sx', 2), ('cz', 1)])
# ...
